# %% [markdown]
# <a href="https://colab.research.google.com/github/26407-cyber/10707/blob/main/2_1_%EC%B6%9C%EB%A0%A5%ED%95%A8%EC%88%98%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 20
b = 50
print('현재 온도는 %d도 습도는 %d%% d 입니다.'%(a, b))
# Out:
# 현재 온도는 20도 습도는 50% d 입니다.
